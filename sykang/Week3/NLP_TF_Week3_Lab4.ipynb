# %% [markdown]
# **Note:** This notebook can run using TensorFlow 2.5.0

# %%
#!pip install tensorflow==2.5.0

# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets

import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# 2.6.0
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteFHPKNG/imdb_reviews-train.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteFHPKNG/imdb_reviews-test.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteFHPKNG/imdb_reviews-unsupervised.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# - 이번에는 imdb set으로 돌아가서 학습을 진행

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and comfortable on the <OOV> and having just eaten a lot however on this occasion i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was causing them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real concern for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %% [markdown]
# 총 3가지 모델을 이용해서 학습을 진행하고 비교
# - GRU
# - LSTM
# - Conv1D

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 169,997
# Trainable params: 169,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 54s 59ms/step - loss: 0.5702 - accuracy: 0.6858 - val_loss: 0.3938 - val_accuracy: 0.8338
# Epoch 2/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.3307 - accuracy: 0.8635 - val_loss: 0.3550 - val_accuracy: 0.8443
# Epoch 3/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.2532 - accuracy: 0.9025 - val_loss: 0.3751 - val_accuracy: 0.8418
# Epoch 4/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.2096 - accuracy: 0.9230 - val_loss: 0.3834 - val_accuracy: 0.8384
# Epoch 5/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.1646 - accuracy: 0.9404 - val_loss: 0.4545 - val_accuracy: 0.8346
# Epoch 6/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.1265 - accuracy: 0.9564 - val_loss: 0.5425 - val_accuracy: 0.8283
# Epoch 7/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0914 - accuracy: 0.9697 - val_loss: 0.5384 - val_accuracy: 0.8210
# Epoch 8/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0615 - accuracy: 0.9808 - val_loss: 0.6601 - val_accuracy: 0.8192
# Epoch 9/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0442 - accuracy: 0.9864 - val_loss: 0.7482 - val_accuracy: 0.8135
# Epoch 10/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0346 - accuracy: 0.9889 - val_loss: 0.8359 - val_accuracy: 0.8115
# Epoch 11/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.8897 - val_accuracy: 0.8114
# Epoch 12/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.9580 - val_accuracy: 0.8072
# Epoch 13/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 1.0245 - val_accuracy: 0.8132
# Epoch 14/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 1.0852 - val_accuracy: 0.8132
# Epoch 15/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 1.0792 - val_accuracy: 0.8143
# Epoch 16/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 1.1092 - val_accuracy: 0.8052
# Epoch 17/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 1.1335 - val_accuracy: 0.8070
# Epoch 18/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0088 - accuracy: 0.9975 - val_loss: 1.2917 - val_accuracy: 0.8140
# Epoch 19/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 1.2558 - val_accuracy: 0.8078
# Epoch 20/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 1.1867 - val_accuracy: 0.8086
# Epoch 21/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 1.3276 - val_accuracy: 0.8112
# Epoch 22/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 1.3297 - val_accuracy: 0.8121
# Epoch 23/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 1.3240 - val_accuracy: 0.8110
# Epoch 24/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 1.3166 - val_accuracy: 0.8051
# Epoch 25/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 1.3454 - val_accuracy: 0.8057
# Epoch 26/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 1.4519 - val_accuracy: 0.8109
# Epoch 27/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 1.3061 - val_accuracy: 0.7971
# Epoch 28/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 1.4217 - val_accuracy: 0.8060
# Epoch 29/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 1.6028 - val_accuracy: 0.8108
# Epoch 30/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 1.3493 - val_accuracy: 0.8045
# Epoch 31/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 1.4639 - val_accuracy: 0.8132
# Epoch 32/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0042 - accuracy: 0.9982 - val_loss: 1.5477 - val_accuracy: 0.8064
# Epoch 33/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 1.5183 - val_accuracy: 0.8083
# Epoch 34/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 1.4988 - val_accuracy: 0.8080
# Epoch 35/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 1.5888 - val_accuracy: 0.8076
# Epoch 36/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 1.6241 - val_accuracy: 0.8084
# Epoch 37/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 1.5808 - val_accuracy: 0.8100
# Epoch 38/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 1.5210 - val_accuracy: 0.8028
# Epoch 39/50
# 782/782 [==============================] - 46s 58ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 1.6359 - val_accuracy: 0.8091
# Epoch 40/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.2463e-04 - accuracy: 1.0000 - val_loss: 1.6956 - val_accuracy: 0.8089
# Epoch 41/50
# 782/782 [==============================] - 45s 58ms/step - loss: 2.3664e-05 - accuracy: 1.0000 - val_loss: 1.7447 - val_accuracy: 0.8094
# Epoch 42/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.3849e-05 - accuracy: 1.0000 - val_loss: 1.7915 - val_accuracy: 0.8099
# Epoch 43/50
# 782/782 [==============================] - 45s 58ms/step - loss: 9.6342e-06 - accuracy: 1.0000 - val_loss: 1.8393 - val_accuracy: 0.8102
# Epoch 44/50
# 782/782 [==============================] - 46s 58ms/step - loss: 6.8083e-06 - accuracy: 1.0000 - val_loss: 1.8866 - val_accuracy: 0.8106
# Epoch 45/50
# 782/782 [==============================] - 45s 58ms/step - loss: 4.8101e-06 - accuracy: 1.0000 - val_loss: 1.9388 - val_accuracy: 0.8108
# Epoch 46/50
# 782/782 [==============================] - 46s 58ms/step - loss: 3.3622e-06 - accuracy: 1.0000 - val_loss: 1.9920 - val_accuracy: 0.8108
# Epoch 47/50
# 782/782 [==============================] - 45s 58ms/step - loss: 2.3255e-06 - accuracy: 1.0000 - val_loss: 2.0471 - val_accuracy: 0.8106
# Epoch 48/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.5980e-06 - accuracy: 1.0000 - val_loss: 2.1061 - val_accuracy: 0.8106
# Epoch 49/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.0873e-06 - accuracy: 1.0000 - val_loss: 2.1653 - val_accuracy: 0.8102
# Epoch 50/50
# 782/782 [==============================] - 45s 58ms/step - loss: 7.3871e-07 - accuracy: 1.0000 - val_loss: 2.2272 - val_accuracy: 0.8106

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
# Model Definition with LSTM
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                12544
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 172,941
# Trainable params: 172,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Definition with Conv1D
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,149
# Trainable params: 171,149
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 전체적으로 파라미터 수에 차이가 있고, 높은 accuracy를 보이지만, overfitting의 문제점을 세 가지 경우 모두 보여주고 있다.
