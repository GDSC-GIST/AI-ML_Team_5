# %% [markdown]
# # **Week 3: Lab 5~6**
# ### Sequence Models

# %% [markdown]
# <br><br>
#
# ---
# ## **Lab 5**
# #### Sarcasm with Bidirectional LSTM

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import numpy as np
import json
import matplotlib.pyplot as plt

# %%
# sarcasm.json
# !gdown --id 1dRzdJS7-cZS4S5CuUc32MZYSLJGkkxnp
# !gdown --id 1xRU3xY5-tkiPGvlz5xBJ18_pHWSRzI4v

vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000


with open("./sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50

training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xRU3xY5-tkiPGvlz5xBJ18_pHWSRzI4v
# To: /content/sarcasm.json
# 100% 5.64M/5.64M [00:00<00:00, 85.0MB/s]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           16000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                12544
# _________________________________________________________________
# dense (Dense)                (None, 24)                1560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 30,129
# Trainable params: 30,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 46s 61ms/step - loss: 0.4648 - accuracy: 0.7704 - val_loss: 0.3909 - val_accuracy: 0.8173
# Epoch 2/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.3538 - accuracy: 0.8392 - val_loss: 0.3743 - val_accuracy: 0.8301
# Epoch 3/50
# 625/625 [==============================] - 37s 59ms/step - loss: 0.3264 - accuracy: 0.8552 - val_loss: 0.3822 - val_accuracy: 0.8250
# Epoch 4/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.3108 - accuracy: 0.8616 - val_loss: 0.3749 - val_accuracy: 0.8302
# Epoch 5/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.2996 - accuracy: 0.8694 - val_loss: 0.3861 - val_accuracy: 0.8289
# Epoch 6/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2899 - accuracy: 0.8733 - val_loss: 0.3824 - val_accuracy: 0.8305
# Epoch 7/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2811 - accuracy: 0.8749 - val_loss: 0.3800 - val_accuracy: 0.8287
# Epoch 8/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2741 - accuracy: 0.8829 - val_loss: 0.4009 - val_accuracy: 0.8269
# Epoch 9/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2671 - accuracy: 0.8846 - val_loss: 0.3948 - val_accuracy: 0.8296
# Epoch 10/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2610 - accuracy: 0.8874 - val_loss: 0.4056 - val_accuracy: 0.8284
# Epoch 11/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2530 - accuracy: 0.8918 - val_loss: 0.4055 - val_accuracy: 0.8269
# Epoch 12/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2469 - accuracy: 0.8960 - val_loss: 0.4241 - val_accuracy: 0.8249
# Epoch 13/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.2388 - accuracy: 0.8963 - val_loss: 0.4318 - val_accuracy: 0.8232
# Epoch 14/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2303 - accuracy: 0.9034 - val_loss: 0.4218 - val_accuracy: 0.8182
# Epoch 15/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2231 - accuracy: 0.9049 - val_loss: 0.4508 - val_accuracy: 0.8220
# Epoch 16/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2163 - accuracy: 0.9101 - val_loss: 0.4630 - val_accuracy: 0.8128
# Epoch 17/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.2083 - accuracy: 0.9139 - val_loss: 0.4831 - val_accuracy: 0.8141
# Epoch 18/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.2015 - accuracy: 0.9164 - val_loss: 0.5345 - val_accuracy: 0.8177
# Epoch 19/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1968 - accuracy: 0.9168 - val_loss: 0.5377 - val_accuracy: 0.8138
# Epoch 20/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1881 - accuracy: 0.9233 - val_loss: 0.5205 - val_accuracy: 0.8147
# Epoch 21/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1807 - accuracy: 0.9255 - val_loss: 0.5723 - val_accuracy: 0.8168
# Epoch 22/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1748 - accuracy: 0.9284 - val_loss: 0.5902 - val_accuracy: 0.8132
# Epoch 23/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1671 - accuracy: 0.9301 - val_loss: 0.5920 - val_accuracy: 0.8113
# Epoch 24/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1600 - accuracy: 0.9345 - val_loss: 0.6377 - val_accuracy: 0.8061
# Epoch 25/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1516 - accuracy: 0.9384 - val_loss: 0.6514 - val_accuracy: 0.8137
# Epoch 26/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1480 - accuracy: 0.9399 - val_loss: 0.6644 - val_accuracy: 0.8046
# Epoch 27/50
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1420 - accuracy: 0.9439 - val_loss: 0.7355 - val_accuracy: 0.8067
# Epoch 28/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1363 - accuracy: 0.9452 - val_loss: 0.7423 - val_accuracy: 0.8019
# Epoch 29/50
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1297 - accuracy: 0.9481 - val_loss: 0.8025 - val_accuracy: 0.8059
# Epoch 30/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.1216 - accuracy: 0.9512 - val_loss: 0.8144 - val_accuracy: 0.8032
# Epoch 31/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.1175 - accuracy: 0.9525 - val_loss: 0.8739 - val_accuracy: 0.7943
# Epoch 32/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.1143 - accuracy: 0.9536 - val_loss: 0.9178 - val_accuracy: 0.7991
# Epoch 33/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.1081 - accuracy: 0.9561 - val_loss: 0.9447 - val_accuracy: 0.7955
# Epoch 34/50
# 625/625 [==============================] - 38s 61ms/step - loss: 0.1001 - accuracy: 0.9588 - val_loss: 1.0142 - val_accuracy: 0.7983
# Epoch 35/50
# 625/625 [==============================] - 38s 62ms/step - loss: 0.1002 - accuracy: 0.9592 - val_loss: 1.0747 - val_accuracy: 0.7989
# Epoch 36/50
# 625/625 [==============================] - 38s 62ms/step - loss: 0.0904 - accuracy: 0.9641 - val_loss: 1.1178 - val_accuracy: 0.7973
# Epoch 37/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0934 - accuracy: 0.9629 - val_loss: 1.0877 - val_accuracy: 0.7959
# Epoch 38/50
# 625/625 [==============================] - 38s 61ms/step - loss: 0.0875 - accuracy: 0.9637 - val_loss: 1.1957 - val_accuracy: 0.7939
# Epoch 39/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0847 - accuracy: 0.9663 - val_loss: 1.2750 - val_accuracy: 0.7958
# Epoch 40/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0751 - accuracy: 0.9708 - val_loss: 1.3228 - val_accuracy: 0.7955
# Epoch 41/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0751 - accuracy: 0.9689 - val_loss: 1.3603 - val_accuracy: 0.7945
# Epoch 42/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0786 - accuracy: 0.9683 - val_loss: 1.3769 - val_accuracy: 0.7983
# Epoch 43/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0693 - accuracy: 0.9721 - val_loss: 1.3811 - val_accuracy: 0.7909
# Epoch 44/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0653 - accuracy: 0.9730 - val_loss: 1.4396 - val_accuracy: 0.7959
# Epoch 45/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0650 - accuracy: 0.9737 - val_loss: 1.5172 - val_accuracy: 0.7991
# Epoch 46/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0660 - accuracy: 0.9732 - val_loss: 1.5703 - val_accuracy: 0.7942
# Epoch 47/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0610 - accuracy: 0.9744 - val_loss: 1.5957 - val_accuracy: 0.7970
# Epoch 48/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0605 - accuracy: 0.9753 - val_loss: 1.5983 - val_accuracy: 0.7934
# Epoch 49/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0581 - accuracy: 0.9757 - val_loss: 1.6418 - val_accuracy: 0.7970
# Epoch 50/50
# 625/625 [==============================] - 39s 62ms/step - loss: 0.0582 - accuracy: 0.9773 - val_loss: 1.6731 - val_accuracy: 0.7889

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
model.save("test.h5")

# %% [markdown]
# <br><br>
#
# ---
# ## **Lab 6**
# #### Sarcasm with 1D Convolutional Layer

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import numpy as np
import json
import matplotlib.pyplot as plt

# %%
# sarcasm.json
# !gdown --id 1dRzdJS7-cZS4S5CuUc32MZYSLJGkkxnp
# !gdown --id 1xRU3xY5-tkiPGvlz5xBJ18_pHWSRzI4v

vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000


with open("./sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50

training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xRU3xY5-tkiPGvlz5xBJ18_pHWSRzI4v
# To: /content/sarcasm.json
# 100% 5.64M/5.64M [00:00<00:00, 89.1MB/s]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 120, 16)           16000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                3096
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 29,489
# Trainable params: 29,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 30s 7ms/step - loss: 0.4742 - accuracy: 0.7591 - val_loss: 0.4007 - val_accuracy: 0.8217
# Epoch 2/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3572 - accuracy: 0.8385 - val_loss: 0.3930 - val_accuracy: 0.8208
# Epoch 3/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3206 - accuracy: 0.8579 - val_loss: 0.4014 - val_accuracy: 0.8198
# Epoch 4/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2879 - accuracy: 0.8742 - val_loss: 0.4091 - val_accuracy: 0.8231
# Epoch 5/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2547 - accuracy: 0.8921 - val_loss: 0.4213 - val_accuracy: 0.8225
# Epoch 6/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2254 - accuracy: 0.9062 - val_loss: 0.4576 - val_accuracy: 0.8188
# Epoch 7/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.1915 - accuracy: 0.9250 - val_loss: 0.5168 - val_accuracy: 0.8146
# Epoch 8/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.1653 - accuracy: 0.9374 - val_loss: 0.5647 - val_accuracy: 0.8117
# Epoch 9/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.1383 - accuracy: 0.9485 - val_loss: 0.6172 - val_accuracy: 0.8028
# Epoch 10/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.1196 - accuracy: 0.9559 - val_loss: 0.6991 - val_accuracy: 0.8001
# Epoch 11/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.1012 - accuracy: 0.9634 - val_loss: 0.7691 - val_accuracy: 0.7986
# Epoch 12/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0840 - accuracy: 0.9706 - val_loss: 0.8794 - val_accuracy: 0.7965
# Epoch 13/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0739 - accuracy: 0.9750 - val_loss: 0.9305 - val_accuracy: 0.7956
# Epoch 14/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0657 - accuracy: 0.9766 - val_loss: 1.0165 - val_accuracy: 0.7985
# Epoch 15/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0590 - accuracy: 0.9791 - val_loss: 1.0750 - val_accuracy: 0.7852
# Epoch 16/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0533 - accuracy: 0.9823 - val_loss: 1.1551 - val_accuracy: 0.7869
# Epoch 17/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0488 - accuracy: 0.9827 - val_loss: 1.3976 - val_accuracy: 0.7880
# Epoch 18/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0462 - accuracy: 0.9830 - val_loss: 1.3921 - val_accuracy: 0.7898
# Epoch 19/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0431 - accuracy: 0.9844 - val_loss: 1.3693 - val_accuracy: 0.7870
# Epoch 20/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0485 - accuracy: 0.9819 - val_loss: 1.4948 - val_accuracy: 0.7924
# Epoch 21/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0385 - accuracy: 0.9856 - val_loss: 1.5210 - val_accuracy: 0.7922
# Epoch 22/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0344 - accuracy: 0.9868 - val_loss: 1.5955 - val_accuracy: 0.7918
# Epoch 23/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0335 - accuracy: 0.9873 - val_loss: 1.6797 - val_accuracy: 0.7924
# Epoch 24/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0337 - accuracy: 0.9875 - val_loss: 1.6944 - val_accuracy: 0.7840
# Epoch 25/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0331 - accuracy: 0.9871 - val_loss: 1.7860 - val_accuracy: 0.7907
# Epoch 26/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0370 - accuracy: 0.9851 - val_loss: 1.7275 - val_accuracy: 0.7873
# Epoch 27/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0317 - accuracy: 0.9876 - val_loss: 1.8844 - val_accuracy: 0.7874
# Epoch 28/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0300 - accuracy: 0.9880 - val_loss: 1.8430 - val_accuracy: 0.7889
# Epoch 29/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0265 - accuracy: 0.9894 - val_loss: 1.9465 - val_accuracy: 0.7825
# Epoch 30/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0267 - accuracy: 0.9891 - val_loss: 1.9009 - val_accuracy: 0.7857
# Epoch 31/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0266 - accuracy: 0.9891 - val_loss: 1.9696 - val_accuracy: 0.7828
# Epoch 32/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0285 - accuracy: 0.9884 - val_loss: 1.9838 - val_accuracy: 0.7834
# Epoch 33/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0287 - accuracy: 0.9883 - val_loss: 2.1974 - val_accuracy: 0.7985
# Epoch 34/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0298 - accuracy: 0.9876 - val_loss: 2.0025 - val_accuracy: 0.7931
# Epoch 35/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0276 - accuracy: 0.9886 - val_loss: 2.1306 - val_accuracy: 0.7903
# Epoch 36/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0251 - accuracy: 0.9894 - val_loss: 2.0593 - val_accuracy: 0.7839
# Epoch 37/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0227 - accuracy: 0.9912 - val_loss: 2.2729 - val_accuracy: 0.7852
# Epoch 38/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0218 - accuracy: 0.9908 - val_loss: 2.1763 - val_accuracy: 0.7892
# Epoch 39/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0252 - accuracy: 0.9892 - val_loss: 2.1315 - val_accuracy: 0.7851
# Epoch 40/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0228 - accuracy: 0.9898 - val_loss: 2.3696 - val_accuracy: 0.7863
# Epoch 41/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0230 - accuracy: 0.9901 - val_loss: 2.3039 - val_accuracy: 0.7822
# Epoch 42/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0191 - accuracy: 0.9920 - val_loss: 2.4135 - val_accuracy: 0.7837
# Epoch 43/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0252 - accuracy: 0.9895 - val_loss: 2.2928 - val_accuracy: 0.7842
# Epoch 44/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0208 - accuracy: 0.9908 - val_loss: 2.2717 - val_accuracy: 0.7809
# Epoch 45/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0213 - accuracy: 0.9901 - val_loss: 2.5594 - val_accuracy: 0.7891
# Epoch 46/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0220 - accuracy: 0.9909 - val_loss: 2.5878 - val_accuracy: 0.7904
# Epoch 47/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0229 - accuracy: 0.9910 - val_loss: 2.4536 - val_accuracy: 0.7900
# Epoch 48/50
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0186 - accuracy: 0.9918 - val_loss: 2.5228 - val_accuracy: 0.7918
# Epoch 49/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0229 - accuracy: 0.9901 - val_loss: 2.3500 - val_accuracy: 0.7818
# Epoch 50/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0211 - accuracy: 0.9908 - val_loss: 2.4812 - val_accuracy: 0.7913

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
model.save("test.h6")
