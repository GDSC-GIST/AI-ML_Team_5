# %% [markdown]
# # **Week 3 Assignment**
# ### Exploring overfitting in NLP

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

import json
import csv
import random
import numpy as np
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

# %%
embedding_dim = 100
max_length = 16
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size=160000
test_portion=.1

corpus = []

# %%
# Note that I cleaned the Stanford dataset to remove LATIN1 encoding to make it easier for Python CSV reader
# You can do that yourself with:
# iconv -f LATIN1 -t UTF8 training.1600000.processed.noemoticon.csv -o training_cleaned.csv

# training_cleaned.csv
# !gdown --id 1wd8KaeCSHxt-nEpMeuHFSNWrDp8joUXJ

num_sentences = 0

with open("./training_cleaned.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        list_item=[]
        
        ### START CODE HERE
        list_item.append(row[5])
        this_label=row[0]
        if this_label=='0':
            list_item.append(0)
        else:
            list_item.append(1)
        ### END CODE HERE
        
        num_sentences = num_sentences + 1
        corpus.append(list_item)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wd8KaeCSHxt-nEpMeuHFSNWrDp8joUXJ
# To: /content/training_cleaned.csv
# 100% 239M/239M [00:04<00:00, 57.2MB/s]

# %%
print(num_sentences)
print(len(corpus))
print(corpus[1])
# Out:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]

# %%
sentences=[]
labels=[]
random.shuffle(corpus)
for x in range(training_size):
    sentences.append(corpus[x][0])# YOUR CODE HERE)
    labels.append(corpus[x][1])# YOUR CODE HERE)


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)# YOUR CODE HERE)

word_index = tokenizer.word_index
vocab_size=len(word_index)# YOUR CODE HERE)

sequences = tokenizer.texts_to_sequences(sentences)# YOUR CODE HERE)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)# YOUR CODE HERE)

split = int(test_portion * training_size)

test_sequences = padded[0:split]# YOUR CODE HERE)
training_sequences = padded[split:training_size]# YOUR CODE HERE)
test_labels = labels[0:split]# YOUR CODE HERE)
training_labels = labels[split:training_size]# YOUR CODE HERE)

# %%
print(vocab_size)
print(word_index['i'])
# Out:
# 138689
# 1

# %%
# Note this is the 100 dimension version of GloVe from Stanford

# glove.6B.100d.txt
# !gdown --id 1W5vZy2etitAblLdFn8_DxnsQKzfFJ98g

embeddings_index = {};
with open('./glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;

embeddings_matrix = np.zeros((vocab_size+1, embedding_dim));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1W5vZy2etitAblLdFn8_DxnsQKzfFJ98g
# To: /content/glove.6B.100d.txt
# 100% 347M/347M [00:03<00:00, 91.1MB/s]

# %%
print(len(embeddings_matrix))
# Out:
# 138690

# %%
model = tf.keras.Sequential([
    # YOUR CODE HERE
    tf.keras.layers.Embedding(vocab_size+1, embedding_dim, input_length=max_length, weights=[embeddings_matrix], trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])# YOUR CODE HERE)
model.summary()

num_epochs = 50

training_padded = np.array(training_sequences)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)

print("Training Complete")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 16, 100)           13869000
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 100)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 12, 64)            32064
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3, 64)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 13,934,153
# Trainable params: 65,153
# Non-trainable params: 13,869,000
# _________________________________________________________________
# Epoch 1/50
# 4500/4500 - 34s - loss: 0.5698 - accuracy: 0.6971 - val_loss: 0.5415 - val_accuracy: 0.7208
# Epoch 2/50
# 4500/4500 - 30s - loss: 0.5296 - accuracy: 0.7296 - val_loss: 0.5082 - val_accuracy: 0.7441
# Epoch 3/50
# 4500/4500 - 30s - loss: 0.5138 - accuracy: 0.7421 - val_loss: 0.5041 - val_accuracy: 0.7490
# Epoch 4/50
# 4500/4500 - 29s - loss: 0.5023 - accuracy: 0.7496 - val_loss: 0.5021 - val_accuracy: 0.7487
# Epoch 5/50
# 4500/4500 - 30s - loss: 0.4926 - accuracy: 0.7559 - val_loss: 0.4992 - val_accuracy: 0.7509
# Epoch 6/50
# 4500/4500 - 29s - loss: 0.4861 - accuracy: 0.7598 - val_loss: 0.4964 - val_accuracy: 0.7536
# Epoch 7/50
# 4500/4500 - 29s - loss: 0.4806 - accuracy: 0.7641 - val_loss: 0.4967 - val_accuracy: 0.7523
# Epoch 8/50
# 4500/4500 - 29s - loss: 0.4761 - accuracy: 0.7669 - val_loss: 0.4987 - val_accuracy: 0.7519
# Epoch 9/50
# 4500/4500 - 29s - loss: 0.4711 - accuracy: 0.7706 - val_loss: 0.5006 - val_accuracy: 0.7524
# Epoch 10/50
# 4500/4500 - 29s - loss: 0.4674 - accuracy: 0.7730 - val_loss: 0.5080 - val_accuracy: 0.7485
# Epoch 11/50
# 4500/4500 - 29s - loss: 0.4630 - accuracy: 0.7751 - val_loss: 0.5023 - val_accuracy: 0.7515
# Epoch 12/50
# 4500/4500 - 29s - loss: 0.4616 - accuracy: 0.7766 - val_loss: 0.5011 - val_accuracy: 0.7511
# Epoch 13/50
# 4500/4500 - 30s - loss: 0.4584 - accuracy: 0.7791 - val_loss: 0.5033 - val_accuracy: 0.7507
# Epoch 14/50
# 4500/4500 - 29s - loss: 0.4551 - accuracy: 0.7805 - val_loss: 0.5059 - val_accuracy: 0.7481
# Epoch 15/50
# 4500/4500 - 29s - loss: 0.4529 - accuracy: 0.7828 - val_loss: 0.5087 - val_accuracy: 0.7509
# Epoch 16/50
# 4500/4500 - 30s - loss: 0.4522 - accuracy: 0.7822 - val_loss: 0.5061 - val_accuracy: 0.7507
# Epoch 17/50
# 4500/4500 - 29s - loss: 0.4506 - accuracy: 0.7838 - val_loss: 0.5124 - val_accuracy: 0.7458
# Epoch 18/50
# 4500/4500 - 29s - loss: 0.4493 - accuracy: 0.7838 - val_loss: 0.5069 - val_accuracy: 0.7492
# Epoch 19/50
# 4500/4500 - 29s - loss: 0.4475 - accuracy: 0.7846 - val_loss: 0.5063 - val_accuracy: 0.7523
# Epoch 20/50
# 4500/4500 - 29s - loss: 0.4458 - accuracy: 0.7859 - val_loss: 0.5085 - val_accuracy: 0.7492
# Epoch 21/50
# 4500/4500 - 29s - loss: 0.4445 - accuracy: 0.7878 - val_loss: 0.5081 - val_accuracy: 0.7486
# Epoch 22/50
# 4500/4500 - 29s - loss: 0.4445 - accuracy: 0.7873 - val_loss: 0.5036 - val_accuracy: 0.7523
# Epoch 23/50
# 4500/4500 - 29s - loss: 0.4437 - accuracy: 0.7876 - val_loss: 0.5131 - val_accuracy: 0.7509
# Epoch 24/50
# 4500/4500 - 29s - loss: 0.4405 - accuracy: 0.7898 - val_loss: 0.5114 - val_accuracy: 0.7496
# Epoch 25/50
# 4500/4500 - 29s - loss: 0.4408 - accuracy: 0.7895 - val_loss: 0.5130 - val_accuracy: 0.7503
# Epoch 26/50
# 4500/4500 - 29s - loss: 0.4396 - accuracy: 0.7895 - val_loss: 0.5115 - val_accuracy: 0.7509
# Epoch 27/50
# 4500/4500 - 29s - loss: 0.4378 - accuracy: 0.7908 - val_loss: 0.5169 - val_accuracy: 0.7488
# Epoch 28/50
# 4500/4500 - 29s - loss: 0.4385 - accuracy: 0.7902 - val_loss: 0.5121 - val_accuracy: 0.7509
# Epoch 29/50
# 4500/4500 - 29s - loss: 0.4360 - accuracy: 0.7922 - val_loss: 0.5111 - val_accuracy: 0.7526
# Epoch 30/50
# 4500/4500 - 29s - loss: 0.4361 - accuracy: 0.7925 - val_loss: 0.5115 - val_accuracy: 0.7511
# Epoch 31/50
# 4500/4500 - 29s - loss: 0.4351 - accuracy: 0.7922 - val_loss: 0.5125 - val_accuracy: 0.7493
# Epoch 32/50
# 4500/4500 - 29s - loss: 0.4335 - accuracy: 0.7921 - val_loss: 0.5162 - val_accuracy: 0.7473
# Epoch 33/50
# 4500/4500 - 29s - loss: 0.4338 - accuracy: 0.7934 - val_loss: 0.5185 - val_accuracy: 0.7467
# Epoch 34/50
# 4500/4500 - 29s - loss: 0.4365 - accuracy: 0.7919 - val_loss: 0.5147 - val_accuracy: 0.7489
# Epoch 35/50
# 4500/4500 - 29s - loss: 0.4361 - accuracy: 0.7922 - val_loss: 0.5151 - val_accuracy: 0.7519
# Epoch 36/50
# 4500/4500 - 29s - loss: 0.4329 - accuracy: 0.7939 - val_loss: 0.5218 - val_accuracy: 0.7449
# Epoch 37/50
# 4500/4500 - 29s - loss: 0.4334 - accuracy: 0.7942 - val_loss: 0.5120 - val_accuracy: 0.7500
# Epoch 38/50
# 4500/4500 - 29s - loss: 0.4324 - accuracy: 0.7938 - val_loss: 0.5134 - val_accuracy: 0.7493
# Epoch 39/50
# 4500/4500 - 29s - loss: 0.4320 - accuracy: 0.7940 - val_loss: 0.5183 - val_accuracy: 0.7469
# Epoch 40/50
# 4500/4500 - 31s - loss: 0.4317 - accuracy: 0.7941 - val_loss: 0.5161 - val_accuracy: 0.7486
# Epoch 41/50
# 4500/4500 - 29s - loss: 0.4326 - accuracy: 0.7949 - val_loss: 0.5189 - val_accuracy: 0.7449
# Epoch 42/50
# 4500/4500 - 29s - loss: 0.4305 - accuracy: 0.7958 - val_loss: 0.5193 - val_accuracy: 0.7486
# Epoch 43/50
# 4500/4500 - 30s - loss: 0.4305 - accuracy: 0.7961 - val_loss: 0.5203 - val_accuracy: 0.7454
# Epoch 44/50
# 4500/4500 - 30s - loss: 0.4300 - accuracy: 0.7948 - val_loss: 0.5227 - val_accuracy: 0.7430
# Epoch 45/50
# 4500/4500 - 30s - loss: 0.4305 - accuracy: 0.7954 - val_loss: 0.5206 - val_accuracy: 0.7466
# Epoch 46/50
# 4500/4500 - 30s - loss: 0.4295 - accuracy: 0.7955 - val_loss: 0.5195 - val_accuracy: 0.7483
# Epoch 47/50
# 4500/4500 - 29s - loss: 0.4297 - accuracy: 0.7961 - val_loss: 0.5157 - val_accuracy: 0.7469
# Epoch 48/50
# 4500/4500 - 29s - loss: 0.4299 - accuracy: 0.7958 - val_loss: 0.5235 - val_accuracy: 0.7524
# Epoch 49/50
# 4500/4500 - 29s - loss: 0.4312 - accuracy: 0.7945 - val_loss: 0.5161 - val_accuracy: 0.7461
# Epoch 50/50
# 4500/4500 - 29s - loss: 0.4296 - accuracy: 0.7959 - val_loss: 0.5184 - val_accuracy: 0.7513
# Training Complete

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])

plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])

plt.figure()
